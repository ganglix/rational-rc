# %% [markdown]
# # membrane module example
# + Raw parameter data
# + initialize model
# + run model
# + calibrate model

# %%
# %matplotlib inline
import numpy as np
from membrane import MembraneModel

# %%
# Case study Raw parameter data
class Param: pass

raw_pars = Param()

# product information
raw_pars.life_product_label_life = 10  # year, defined as 95% confident non-failure
raw_pars.life_std = 0.2 * raw_pars.life_product_label_life # assume if not known, calibrate later for real service conditions
raw_pars.life_confidence = 0.95

# calibration data (if available)
# field survey result
raw_pars.membrane_failure_ratio_field = 0.01
raw_pars.membrane_age_field = 5  # [year]

# %%
# initialize model
mem_model = MembraneModel(raw_pars)

# run and postproc (uncalibrated)
mem_model.run(10)  # 10 years
mem_model.postproc(plot=True)
# Out:
# Pf(g = R-S < 0) from various methods
#     sample count: 0.04914
#     g integral: 0.050161630548833894
#     R S integral: 0.05000000000001138
#     beta_factor: 1.6513450197246102
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5755c7cd2f08> in <module>
#       4 # run and postproc (uncalibrated)
#       5 mem_model.run(10)  # 10 years
# ----> 6 mem_model.postproc(plot=True)
#
# ~/Local Documents/Mitacs project local/Tinkrete/modules/membrane.py in postproc(self, plot)
#     406             self.age,
#     407             R_distrib_type="normal",
# --> 408             plot=plot,
#     409         )
#     410         self.pf = sol[0]
#
# ~/Local Documents/Mitacs project local/Tinkrete/modules/membrane.py in pf_RS_special(R_info, S, R_distrib_type, plot)
#     141             xy=(0, g.mean()),
#     142             xytext=(g.mean(), g_kde_fit(0)[0]),
# --> 143             va="center",
#     144         )
#     145         ax2.legend()
#
# TypeError: annotate() missing 1 required positional argument: 'text'

# %%
# calibration to field data 
mem_model_cal = mem_model.calibrate(raw_pars.membrane_age_field, raw_pars.membrane_failure_ratio_field)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-dd51a6853592> in <module>
#       1 # calibration to field data
# ----> 2 mem_model_cal = mem_model.calibrate(raw_pars.membrane_age_field, raw_pars.membrane_failure_ratio_field)
#       3
#
# NameError: name 'mem_model' is not defined

# %%
# run and postproc (calibrated)
mem_model_cal.run(10)  # 10 years
mem_model_cal.postproc(plot=True)
# Out:
# Pf(g = R-S < 0) from various methods
#     sample count: 0.17761
#     g integral: 0.1791927385519138
#     R S integral: 0.17795324587799488
#     beta_factor: 0.9208084394524149

# %%
# model with a list of time steps
t_lis = np.arange(0,21,1)
pf_lis, beta_lis = mem_model_cal.membrane_failure_with_year(year_lis=t_lis, plot=True, amplify=30)
